# %%
import pandas as pd

# %%
# Combining several dozen excel worksheets with a total of aprox 15 mil rows into a pandas dataframe.

# %%
S1_alameda1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_alameda.xlsx",sheet_name= "2015", header = None)

# %%
S1_alameda2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_alameda.xlsx",sheet_name= "2019", header = None)

# %%
S1_alamo1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_alamo.xlsx",sheet_name= "2015", header = None)

# %%
S1_alamo2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_alamo.xlsx",sheet_name= "2019", header = None)

# %%
S1_berkley1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_berkley.xlsx",sheet_name= "2015", header = None)

# %%
S1_berkley2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_berkley.xlsx",sheet_name= "2019", header = None)

# %%
S1_crockett1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_crockett.xlsx",sheet_name= "2015", header = None)

# %%
S1_crockett2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_crockett.xlsx",sheet_name= "2019", header = None)

# %%
S1_danville1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_danville.xlsx",sheet_name= "2015", header = None)

# %%
S1_danville2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_danville.xlsx",sheet_name= "2019", header = None)

# %%
S1_hercules1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_hercules .xlsx",sheet_name= "2015", header = None)

# %%
S1_hercules2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_hercules .xlsx",sheet_name= "2019", header = None)

# %%
S1_leandro1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_leandro.xlsx",sheet_name= "2015", header = None)

# %%
S1_leandro2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_leandro.xlsx",sheet_name= "2019", header = None)

# %%
S1_lorenzo1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_lorenzo.xlsx",sheet_name= "2015", header = None)

# %%
S1_lorenzo2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_lorenzo.xlsx",sheet_name= "2019", header = None)

# %%
S1_moraga1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_moraga .xlsx",sheet_name= "2015", header = None)

# %%
S1_moraga2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_moraga .xlsx",sheet_name= "2019", header = None)

# %%
S1_oakland_a1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_oakland_a1.xlsx", header=None)

# %%
S1_oakland_a2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_oakland_a2.xlsx", header=None)

# %%
S1_oakland_a3 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_oakland_a3.xlsx", header=None)

# %%
S1_oakland_b1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_oakland_b1.xlsx", header=None)

# %%
S1_oakland_b2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_oakland_b2.xlsx", header=None)

# %%
S1_oakland_b3 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_oakland_b3.xlsx", header=None)

# %%
S1_orinda1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_orinda .xlsx",sheet_name= "2015", header = None)

# %%
S1_orinda2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_orinda .xlsx",sheet_name= "2019", header = None)

# %%
S1_pablo1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_pablo .xlsx",sheet_name= "2015", header = None)

# %%
S1_pablo2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_pablo .xlsx",sheet_name= "2019", header = None)

# %%
S1_richmond1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_richmond.xlsx",sheet_name= "2015", header = None)

# %%
S1_richmond2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_richmond.xlsx",sheet_name= "2019", header = None)

# %%
S1_selby1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_selby.xlsx",sheet_name= "2015", header = None)

# %%
S1_selby2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_selby.xlsx",sheet_name= "2019", header = None)

# %%
S1_sobrante1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_sobrante.xlsx",sheet_name= "2015", header = None)

# %%
S1_sobrante2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_sobrante.xlsx",sheet_name= "2019", header = None)

# %%
S1_wc1 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_wc .xlsx",sheet_name= "2015", header = None)

# %%
S1_wc2 = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S1_wc .xlsx",sheet_name= "2019", header = None)

# %%
S2_alameda = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_alameda.xlsx")

# %%
S2_alamo = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_alamo.xlsx")

# %%
S2_berkeley = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_berkeley .xlsx")

# %%
S2_crockett = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_crockett.xlsx")

# %%
S2_danville = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_danville.xlsx")

# %%
S2_hercules = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_hercules.xlsx")

# %%
S2_leandro = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_leandro .xlsx")

# %%
S2_lorenzo = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_lorenzo .xlsx")

# %%
S2_moraga = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_moraga.xlsx")

# %%
S2_oakland = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_oakland .xlsx")

# %%
S2_orinda = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_orinda .xlsx")

# %%
S2_pablo = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_pablo.xlsx")

# %%
s2_richmond = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\s2_richmond.xlsx")

# %%
S2_selby = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_selby .xlsx")

# %%
S2_sobrante = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_sobrante.xlsx")

# %%
S2_wc = pd.read_excel(r"C:\Users\detro\Desktop\Edited_Pj_city_water\ALL\S2_wc.xlsx")

# %%
S2_alameda.head()
# Out:
#   Pseudo ID   BCC BEGIN_DATE   END_DATE  CCF  ELEVATION_BAND CITY_NAME  \
# 0   94501-1  8800  12/8/2015  2/10/2016  4.0               1   Alameda
# 1   94501-1  8800  2/10/2016   4/9/2016  4.0               1   Alameda
# 2   94501-1  8800  10/7/2015  12/8/2015  5.0               1   Alameda
# 3   94501-1  8800   8/7/2015  10/7/2015  4.0               1   Alameda
# 4   94501-1  8800   6/9/2015   8/7/2015  3.0               1   Alameda
#
#     ZIP_CODE
# 0  945014615
# 1  945014615
# 2  945014615
# 3  945014615
# 4  945014615

# %%
S1_alameda1.head()
# Out:
#             0     1          2          3   4  5        6          7
# 0  94502-4797  8800 2012-04-05 2012-06-05  26  1  Alameda  945027714
# 1  94502-4797  8800 2012-06-05 2012-08-03  32  1  Alameda  945027714
# 2  94502-4797  8800 2012-08-03 2012-10-03  30  1  Alameda  945027714
# 3  94502-4797  8800 2012-10-03 2012-12-04  21  1  Alameda  945027714
# 4  94502-4797  8800 2012-12-04 2013-02-05  20  1  Alameda  945027714

# %%
# concat'ing the first series.

# %%
frames = [S1_alameda1, S1_alameda2, S1_alamo1, S1_alamo2, S1_berkley1, S1_berkley2, S1_crockett1, S1_crockett2, S1_danville1, 
          S1_danville2, S1_hercules1, S1_hercules2, S1_leandro1, S1_leandro2, S1_lorenzo1, S1_lorenzo2, S1_moraga1,
          S1_moraga2, S1_oakland_a1, S1_oakland_a2, S1_oakland_a3, S1_oakland_b1, S1_oakland_b2, S1_oakland_b3, S1_orinda1, 
          S1_orinda2, S1_pablo1, S1_pablo2, S1_richmond1, S1_richmond2, S1_selby1, S1_selby2, S1_sobrante1, S1_sobrante2,
          S1_wc1, S1_wc2]
series1 = pd.concat(frames)

# %%
series1.head()
# Out:
#             0       1          2          3     4    5        6            7
# 0  94502-4797  8800.0 2012-04-05 2012-06-05  26.0  1.0  Alameda  945027714.0
# 1  94502-4797  8800.0 2012-06-05 2012-08-03  32.0  1.0  Alameda  945027714.0
# 2  94502-4797  8800.0 2012-08-03 2012-10-03  30.0  1.0  Alameda  945027714.0
# 3  94502-4797  8800.0 2012-10-03 2012-12-04  21.0  1.0  Alameda  945027714.0
# 4  94502-4797  8800.0 2012-12-04 2013-02-05  20.0  1.0  Alameda  945027714.0

# %%
# concat'ing the second series.

# %%
frames = [S2_alameda, S2_alamo, S2_berkeley, S2_crockett, S2_danville, S2_hercules, 
         S2_leandro, S2_lorenzo, S2_moraga, S2_oakland, S2_orinda, S2_pablo, s2_richmond, S2_selby, S2_sobrante, S2_wc]
series2 = pd.concat(frames)

# %%
series2.head()
# Out:
#   Pseudo ID     BCC BEGIN_DATE   END_DATE  CCF  ELEVATION_BAND CITY_NAME  \
# 0   94501-1  8800.0  12/8/2015  2/10/2016  4.0             1.0   Alameda
# 1   94501-1  8800.0  2/10/2016   4/9/2016  4.0             1.0   Alameda
# 2   94501-1  8800.0  10/7/2015  12/8/2015  5.0             1.0   Alameda
# 3   94501-1  8800.0   8/7/2015  10/7/2015  4.0             1.0   Alameda
# 4   94501-1  8800.0   6/9/2015   8/7/2015  3.0             1.0   Alameda
#
#       ZIP_CODE Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  945014615.0        NaN        NaN        NaN        NaN        NaN
# 1  945014615.0        NaN        NaN        NaN        NaN        NaN
# 2  945014615.0        NaN        NaN        NaN        NaN        NaN
# 3  945014615.0        NaN        NaN        NaN        NaN        NaN
# 4  945014615.0        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0        NaN        NaN        NaN
# ...

# %%
# cleaning up the series data in prep to merge.

# %%
series2_1= series2.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 
                        'Unnamed: 6', 'Unnamed: 7'], axis=1)

# %%
series2_1.head()
# Out:
#   Pseudo ID     BCC BEGIN_DATE   END_DATE  CCF  ELEVATION_BAND CITY_NAME  \
# 0   94501-1  8800.0  12/8/2015  2/10/2016  4.0             1.0   Alameda
# 1   94501-1  8800.0  2/10/2016   4/9/2016  4.0             1.0   Alameda
# 2   94501-1  8800.0  10/7/2015  12/8/2015  5.0             1.0   Alameda
# 3   94501-1  8800.0   8/7/2015  10/7/2015  4.0             1.0   Alameda
# 4   94501-1  8800.0   6/9/2015   8/7/2015  3.0             1.0   Alameda
#
#       ZIP_CODE
# 0  945014615.0
# 1  945014615.0
# 2  945014615.0
# 3  945014615.0
# 4  945014615.0

# %%
series2_1.count()
# Out:
# Pseudo ID         2559674
# BCC               2559674
# BEGIN_DATE        2559674
# END_DATE          2559674
# CCF               2559674
# ELEVATION_BAND    2559581
# CITY_NAME         2559674
# ZIP_CODE          2559674
# dtype: int64

# %%
series2_2 = series2_1[['Pseudo ID', 'BCC', 'BEGIN_DATE', 'END_DATE', 'CCF', 'ELEVATION_BAND', 'CITY_NAME', 'ZIP_CODE' ]].copy()

# %%
series2_2.head()
# Out:
#   Pseudo ID     BCC BEGIN_DATE   END_DATE  CCF  ELEVATION_BAND CITY_NAME  \
# 0   94501-1  8800.0  12/8/2015  2/10/2016  4.0             1.0   Alameda
# 1   94501-1  8800.0  2/10/2016   4/9/2016  4.0             1.0   Alameda
# 2   94501-1  8800.0  10/7/2015  12/8/2015  5.0             1.0   Alameda
# 3   94501-1  8800.0   8/7/2015  10/7/2015  4.0             1.0   Alameda
# 4   94501-1  8800.0   6/9/2015   8/7/2015  3.0             1.0   Alameda
#
#       ZIP_CODE
# 0  945014615.0
# 1  945014615.0
# 2  945014615.0
# 3  945014615.0
# 4  945014615.0

# %%
series2 = series2_2

# %%
series2.head()
# Out:
#   Pseudo ID     BCC BEGIN_DATE   END_DATE  CCF  ELEVATION_BAND CITY_NAME  \
# 0   94501-1  8800.0  12/8/2015  2/10/2016  4.0             1.0   Alameda
# 1   94501-1  8800.0  2/10/2016   4/9/2016  4.0             1.0   Alameda
# 2   94501-1  8800.0  10/7/2015  12/8/2015  5.0             1.0   Alameda
# 3   94501-1  8800.0   8/7/2015  10/7/2015  4.0             1.0   Alameda
# 4   94501-1  8800.0   6/9/2015   8/7/2015  3.0             1.0   Alameda
#
#       ZIP_CODE
# 0  945014615.0
# 1  945014615.0
# 2  945014615.0
# 3  945014615.0
# 4  945014615.0

# %%
series1.head()
# Out:
#             0       1          2          3     4    5        6            7
# 0  94502-4797  8800.0 2012-04-05 2012-06-05  26.0  1.0  Alameda  945027714.0
# 1  94502-4797  8800.0 2012-06-05 2012-08-03  32.0  1.0  Alameda  945027714.0
# 2  94502-4797  8800.0 2012-08-03 2012-10-03  30.0  1.0  Alameda  945027714.0
# 3  94502-4797  8800.0 2012-10-03 2012-12-04  21.0  1.0  Alameda  945027714.0
# 4  94502-4797  8800.0 2012-12-04 2013-02-05  20.0  1.0  Alameda  945027714.0

# %%
series1.head()
# Out:
#             0       1          2          3     4    5        6            7
# 0  94502-4797  8800.0 2012-04-05 2012-06-05  26.0  1.0  Alameda  945027714.0
# 1  94502-4797  8800.0 2012-06-05 2012-08-03  32.0  1.0  Alameda  945027714.0
# 2  94502-4797  8800.0 2012-08-03 2012-10-03  30.0  1.0  Alameda  945027714.0
# 3  94502-4797  8800.0 2012-10-03 2012-12-04  21.0  1.0  Alameda  945027714.0
# 4  94502-4797  8800.0 2012-12-04 2013-02-05  20.0  1.0  Alameda  945027714.0

# %%
# using different methods to create column headers.

# %%
series1.columns = ['Pseudo ID', 'BCC', 'BEGIN_DATE', 'END_DATE', 'CCF', 'ELEVATION_BAND', 'CITY_NAME', 'ZIP_CODE']

# %%
series1.head()
# Out:
#     Pseudo ID     BCC BEGIN_DATE   END_DATE   CCF  ELEVATION_BAND CITY_NAME  \
# 0  94502-4797  8800.0 2012-04-05 2012-06-05  26.0             1.0   Alameda
# 1  94502-4797  8800.0 2012-06-05 2012-08-03  32.0             1.0   Alameda
# 2  94502-4797  8800.0 2012-08-03 2012-10-03  30.0             1.0   Alameda
# 3  94502-4797  8800.0 2012-10-03 2012-12-04  21.0             1.0   Alameda
# 4  94502-4797  8800.0 2012-12-04 2013-02-05  20.0             1.0   Alameda
#
#       ZIP_CODE
# 0  945027714.0
# 1  945027714.0
# 2  945027714.0
# 3  945027714.0
# 4  945027714.0

# %%
# concat'ing both series into a single dataframe.

# %%
frames = [series1, series2]
water_use = pd.concat(frames)

# %%
water_use.count()
# Out:
# Pseudo ID         15054584
# BCC               15054632
# BEGIN_DATE        15054632
# END_DATE          15054632
# CCF               15054632
# ELEVATION_BAND    15054539
# CITY_NAME         15054632
# ZIP_CODE          15054632
# dtype: int64

# %%
#I now have the excel files all combined into a single DF. Time to deal with duplicates.

# %%
dups = water_use[water_use.duplicated()]

# %%
dups.count()
# Out:
# Pseudo ID         754
# BCC               754
# BEGIN_DATE        754
# END_DATE          754
# CCF               754
# ELEVATION_BAND    754
# CITY_NAME         754
# ZIP_CODE          754
# dtype: int64

# %%
water_use = water_use.drop_duplicates()

# %%
water_use.count()
# Out:
# Pseudo ID         15053830
# BCC               15053878
# BEGIN_DATE        15053878
# END_DATE          15053878
# CCF               15053878
# ELEVATION_BAND    15053785
# CITY_NAME         15053878
# ZIP_CODE          15053878
# dtype: int64

# %%
#Check dup drop count

15054632 - 15053878
# Out:
# 754

# %%
#Check for Null values

water_use.isnull().values.any()
# Out:
# True

# %%
water_use.isnull().sum().sum()
# Out:
# 149

# %%
water_use.dropna(how='any', inplace=True)

# %%
water_use.isnull().sum().sum()
# Out:
# 0

# %%
water_use.dtypes
# Out:
# Pseudo ID          object
# BCC               float64
# BEGIN_DATE         object
# END_DATE           object
# CCF               float64
# ELEVATION_BAND    float64
# CITY_NAME          object
# ZIP_CODE          float64
# dtype: object

# %%
water_use.columns = ['Pseudo_Id', 'Customer_Type', 'Start_Date', 'End_Date', 'Ccf_Used', 'Elevation_Band', 'City', 'Zip_Code' ]

# %%
water_use.head()
# Out:
#     Pseudo_Id  Customer_Type           Start_Date             End_Date  \
# 0  94502-4797         8800.0  2012-04-05 00:00:00  2012-06-05 00:00:00
# 1  94502-4797         8800.0  2012-06-05 00:00:00  2012-08-03 00:00:00
# 2  94502-4797         8800.0  2012-08-03 00:00:00  2012-10-03 00:00:00
# 3  94502-4797         8800.0  2012-10-03 00:00:00  2012-12-04 00:00:00
# 4  94502-4797         8800.0  2012-12-04 00:00:00  2013-02-05 00:00:00
#
#    Ccf_Used  Elevation_Band     City     Zip_Code
# 0      26.0             1.0  Alameda  945027714.0
# 1      32.0             1.0  Alameda  945027714.0
# 2      30.0             1.0  Alameda  945027714.0
# 3      21.0             1.0  Alameda  945027714.0
# 4      20.0             1.0  Alameda  945027714.0

# %%
# Converting customer codes into strings with proper descriptions

# %%
water_use['Customer_Type'].unique()
# Out:
# array([8800., 6513., 6514., 5300., 7900., 6800., 7500., 5812., 7200.,
#        7950., 8000., 4400., 7260., 5811., 2051., 4200., 4950., 8200.,
#        5400., 7990., 8600., 5813., 5540., 4800., 7020.,  100., 1500.,
#        2820., 7600., 4900.,  700., 2900., 7300., 7215., 2500., 3590.,
#        7001., 3400., 3730., 7542., 2700., 2300., 3200., 7216., 8060.,
#        3700., 5000., 7000., 4500., 2050., 7210., 3900., 2090., 7940.,
#        2891., 3600., 4100., 2830., 6500., 3500., 2060., 3800., 3300.,
#        4700., 3470., 2850., 2010., 7342., 2400., 4000., 2080., 2810.,
#        2040., 7218., 2011., 5093., 2840., 2030., 2600., 3000., 7539.,
#        1200., 7699., 2020., 2860.])

# %%
water_use = water_use.astype({'Customer_Type':'string'})

# %%
# Making sure to code types by a three letter categories (Res/Com) for easy future selection

# %%
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['8800'], 'Res_Single_Family')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['6514'], 'Res_Multiple_Dwelling')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['6513'], 'Res_Apartments')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2010'], 'Com_Meat_Products')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2011'], 'Com_Slaughterhouses')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2020'], 'Com_Dairy Product Processing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2030'], 'Com_Fruit_Vegetable_Processing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2040'], 'Com_Grain_Mills')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2050'], 'Com_Bakeries')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2060'], 'Com_Sugar_Processing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2077'], 'Com_Rendering_Tallow')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2080'], 'Com_Beverage_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2090'], 'Com_Specialty_Foods_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2600'], 'Com_Paper_Products')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2910'], 'Com_Inorganic_Chemicals_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2820'], 'Com_Synthetic_Materials_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2830'], 'Com_Drug_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2840'], 'Com_Cleaning_Products')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2850'], 'Com_Paint_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['2893'], 'Com_Ink_Pigment_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['3110'], 'Com_Leather_Tanning_Finishing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['3200'], 'Com_Earthware_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['3300'], 'Com_Primary_Metals_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['3400'], 'Com_Metal_Products_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['3410'], 'Com_Drum_Barrel_Manufacturing')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['3470'], 'Com_Metal_Coating')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['4500'], 'Com_Air_Transportation')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['4951'], 'Com_Groundwater_Remediation')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['5812'], 'Com_Food_Service_Establishments')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['7000'], 'Com_Hotels_Motels_Food_Service')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['7210'], 'Com_Laundries')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['7215'], 'Com_Laundromats')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['7218'], 'Com_Industrial_Laundries')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['7300'], 'Com_Laboratories')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['7542'], 'Com_Auto_Wash')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['8060'], 'Com_Hospitals')
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['8060'], 'Com_Schools')

# %%
water_use['Customer_Type'].unique()
# Out:
# <StringArray>
# [                    'Res_Single_Family',
#                         'Res_Apartments',
#                  'Res_Multiple_Dwelling',
#                                   '5300',
#                                   '7900',
#                                   '6800',
#                                   '7500',
#        'Com_Food_Service_Establishments',
#                                   '7200',
#                                   '7950',
#                                   '8000',
#                                   '4400',
#                                   '7260',
#                                   '5811',
#                                   '2051',
#                                   '4200',
#                                   '4950',
#                                   '8200',
#                                   '5400',
#                                   '7990',
#                                   '8600',
#                                   '5813',
# ...

# %%
water_use['Customer_Type'] = water_use['Customer_Type'].replace(['5300', '7900', '6800', '7500', '7200', '7950', '8000', '4400', '7260', '5811', '2051', '4200', '4950', 
'8200', '5400', '7990', '8600', '5813', '5540', '4800', '7020', '0100', '1500', '7600', '4900', '0700', 
'2900', '2500', '3590', '7001', '3730', '2700', '2300', '7216', '3700', '5000', '3900', '7940', '2891', 
'BCC', '3600', '4100', '6500', '3500', '3800', '4700', '7342', '2400', '4000', '2810', '5093', '3000', 
'7539', '1200' ,'7699' ,'2860', '100', '700', ], 'Com_Misc_Other')

# %%
water_use['Customer_Type'].unique()
# Out:
# <StringArray>
# [                    'Res_Single_Family',
#                         'Res_Apartments',
#                  'Res_Multiple_Dwelling',
#                         'Com_Misc_Other',
#        'Com_Food_Service_Establishments',
#  'Com_Synthetic_Materials_Manufacturing',
#                       'Com_Laboratories',
#                        'Com_Laundromats',
#       'Com_Metal_Products_Manufacturing',
#                          'Com_Auto_Wash',
#            'Com_Earthware_Manufacturing',
#                          'Com_Hospitals',
#         'Com_Hotels_Motels_Food_Service',
#                 'Com_Air_Transportation',
#                           'Com_Bakeries',
#                          'Com_Laundries',
#      'Com_Specialty_Foods_Manufacturing',
#                 'Com_Drug_Manufacturing',
#                   'Com_Sugar_Processing',
#       'Com_Primary_Metals_Manufacturing',
#                      'Com_Metal_Coating',
#                'Com_Paint_Manufacturing',
# ...

# %%
water_use.dtypes
# Out:
# Pseudo_Id          object
# Customer_Type      string
# Start_Date         object
# End_Date           object
# Ccf_Used          float64
# Elevation_Band    float64
# City               object
# Zip_Code          float64
# dtype: object

# %%
water_use = water_use.astype({'Ccf_Used':'int'})

# %%
water_use.dtypes
# Out:
# Pseudo_Id          object
# Customer_Type      string
# Start_Date         object
# End_Date           object
# Ccf_Used            int32
# Elevation_Band    float64
# City               object
# Zip_Code          float64
# dtype: object

# %%
# Converting columns to proper data types

# %%
water_use = water_use.astype({'Zip_Code':'string'})

# %%
water_use = water_use.astype({'Elevation_Band':'int'})

# %%
water_use = water_use.astype({'Pseudo_Id':'string'})

# %%
# Building out CCF into Daily Water Use for easier comprehension and component of new data categories

# %%
water_use[['Start_Date','End_Date']] = water_use[['Start_Date','End_Date']].apply(pd.to_datetime) 
water_use['Billed_Days'] = (water_use['End_Date'] - water_use['Start_Date']).dt.days

# %%
water_use.dtypes
# Out:
# Pseudo_Id                 string
# Customer_Type             string
# Start_Date        datetime64[ns]
# End_Date          datetime64[ns]
# Ccf_Used                   int32
# Elevation_Band             int32
# City                      object
# Zip_Code                  string
# Billed_Days                int64
# dtype: object

# %%
water_use['Gallons_Used'] = (water_use['Ccf_Used'] * 748)

# %%
water_use['Gallons_Used_Daily'] = (water_use['Gallons_Used']) / (water_use['Billed_Days'])

# %%
water_use.head()
# Out:
#     Pseudo_Id      Customer_Type Start_Date   End_Date  Ccf_Used  \
# 0  94502-4797  Res_Single_Family 2012-04-05 2012-06-05        26
# 1  94502-4797  Res_Single_Family 2012-06-05 2012-08-03        32
# 2  94502-4797  Res_Single_Family 2012-08-03 2012-10-03        30
# 3  94502-4797  Res_Single_Family 2012-10-03 2012-12-04        21
# 4  94502-4797  Res_Single_Family 2012-12-04 2013-02-05        20
#
#    Elevation_Band     City     Zip_Code  Billed_Days  Gallons_Used  \
# 0               1  Alameda  945027714.0           61         19448
# 1               1  Alameda  945027714.0           59         23936
# 2               1  Alameda  945027714.0           61         22440
# 3               1  Alameda  945027714.0           62         15708
# 4               1  Alameda  945027714.0           63         14960
#
#    Gallons_Used_Daily
# 0          318.819672
# 1          405.694915
# 2          367.868852
# 3          253.354839
# 4          237.460317

# %%
water_use.dtypes
# Out:
# Pseudo_Id                     string
# Customer_Type                 string
# Start_Date            datetime64[ns]
# End_Date              datetime64[ns]
# Ccf_Used                       int32
# Elevation_Band                 int32
# City                          object
# Zip_Code                      string
# Billed_Days                    int64
# Gallons_Used                   int32
# Gallons_Used_Daily           float64
# dtype: object

# %%
water_use = water_use.astype({'Gallons_Used_Daily':'int'})

# %%
water_use['Start_Date'].min()
# Out:
# Timestamp('2012-04-01 00:00:00')

# %%
water_use['End_Date'].max()
# Out:
# Timestamp('2019-05-31 00:00:00')

# %%
drought = pd.read_csv(r"C:\Users\detro/droughts.csv")

# %%
drought.head()
# Out:
#    Unnamed: 0        Date  None    D0     D1     D2   D3   D4  \
# 0           0  2012-04-02  2.22  8.16  43.36  46.25  0.0  0.0
# 1           1  2012-04-03  2.22  8.16  43.36  46.25  0.0  0.0
# 2           2  2012-04-04  2.22  8.16  43.36  46.25  0.0  0.0
# 3           3  2012-04-05  2.22  8.16  43.36  46.25  0.0  0.0
# 4           4  2012-04-06  2.22  8.16  43.36  46.25  0.0  0.0
#
#    Drought_intensity
# 0             46.726
# 1             46.726
# 2             46.726
# 3             46.726
# 4             46.726

# %%
drought = drought.drop('Unnamed: 0', axis=1)

# %%
drought['Date'] = pd.to_datetime(drought['Date'])

# %%
drought.dtypes
# Out:
# Date                 datetime64[ns]
# None                        float64
# D0                          float64
# D1                          float64
# D2                          float64
# D3                          float64
# D4                          float64
# Drought_intensity           float64
# dtype: object

# %%
water_use.head()
# Out:
#     Pseudo_Id      Customer_Type Start_Date   End_Date  Ccf_Used  \
# 0  94502-4797  Res_Single_Family 2012-04-05 2012-06-05        26
# 1  94502-4797  Res_Single_Family 2012-06-05 2012-08-03        32
# 2  94502-4797  Res_Single_Family 2012-08-03 2012-10-03        30
# 3  94502-4797  Res_Single_Family 2012-10-03 2012-12-04        21
# 4  94502-4797  Res_Single_Family 2012-12-04 2013-02-05        20
#
#    Elevation_Band     City     Zip_Code  Billed_Days  Gallons_Used  \
# 0               1  Alameda  945027714.0           61         19448
# 1               1  Alameda  945027714.0           59         23936
# 2               1  Alameda  945027714.0           61         22440
# 3               1  Alameda  945027714.0           62         15708
# 4               1  Alameda  945027714.0           63         14960
#
#    Gallons_Used_Daily
# 0                 318
# 1                 405
# 2                 367
# 3                 253
# 4                 237

# %%
# Resetting the index in prepration for merging in drought values from the drought sheet.

# %%
water_use = water_use.reset_index()

# %%
water_use.index.is_unique
# Out:
# True

# %%
water_use.count()
# Out:
# index                 15053737
# Pseudo_Id             15053737
# Customer_Type         15053737
# Start_Date            15053737
# End_Date              15053737
# Ccf_Used              15053737
# Elevation_Band        15053737
# City                  15053737
# Zip_Code              15053737
# Billed_Days           15053737
# Gallons_Used          15053737
# Gallons_Used_Daily    15053737
# dtype: int64

# %%
import numpy as np

# %%
# Defining a list that will apply a mask in a for loop to our coulumns by date, to add drought factor from the drought table

# %%
dummy_list = range(15053737)

# %%
outlist = []
for i in dummy_list:
    
    mask3 = drought[(drought.Date >= water_use.loc[i, 'Start_Date']) & (drought.Date <= water_use.loc[i, 'End_Date'])] 
    m11 = mask3['Drought_intensity'].sum()
    if i > 0:
        (outlist.append(m22))
        if i == 15053737:
            break 
    m22 = m11/(water_use.loc[i, 'Billed_Days'])

# %%
outlist
# Out:
# [37.38167213114753,
#  34.03159322033899,
#  36.45645901639345,
#  37.09174193548386,
#  30.98326984126984,
#  31.655645161290323,
#  42.131333333333345,
#  56.32763333333334,
#  60.7615593220339,
#  59.254866666666665,
#  63.90314285714285,
#  75.77900000000004,
#  80.36013559322036,
#  83.65403278688528,
#  89.00944827586206,
#  87.98377419354841,
#  83.731625,
#  33.6486440677966,
#  35.11477966101695,
#  36.948885245901636,
#  34.94866666666666,
#  29.178833333333333,
#  34.762295081967224,
#  49.92103448275863,
#  59.8781935483871,
#  59.915423728813565,
#  60.45633333333334,
#  70.52793333333334,
#  78.4078596491228,
#  81.69987301587302,
#  87.00203636363636,
#  88.54661290322579,
#  86.10964179104475,
#  82.27463333333334,
#  88.84149999999995,
#  82.47378787878789,
#  34.36756666666666,
#  34.574645161290334,
#  36.779966101694924,
#  36.57351612903225,
#  29.1093125,
#  33.47298360655738,
#  45.997448275862084,
#  58.22734426229509,
#  60.60945762711864,
# ...

# %%
len(outlist)
# Out:
# 15053736

# %%
len(dummy_list)
# Out:
# 15053737

# %%
drought_df = pd.DataFrame (outlist, columns = ['Drought_Factor'])

# %%
drought_df.head()
# Out:
#    Drought_Factor
# 0       37.381672
# 1       34.031593
# 2       36.456459
# 3       37.091742
# 4       30.983270

# %%
drought_df.count()
# Out:
# Drought_Factor    15053736
# dtype: int64

# %%
water_use.head()
# Out:
#    index   Pseudo_Id      Customer_Type Start_Date   End_Date  Ccf_Used  \
# 0      0  94502-4797  Res_Single_Family 2012-04-05 2012-06-05        26
# 1      1  94502-4797  Res_Single_Family 2012-06-05 2012-08-03        32
# 2      2  94502-4797  Res_Single_Family 2012-08-03 2012-10-03        30
# 3      3  94502-4797  Res_Single_Family 2012-10-03 2012-12-04        21
# 4      4  94502-4797  Res_Single_Family 2012-12-04 2013-02-05        20
#
#    Elevation_Band     City     Zip_Code  Billed_Days  Gallons_Used  \
# 0               1  Alameda  945027714.0           61         19448
# 1               1  Alameda  945027714.0           59         23936
# 2               1  Alameda  945027714.0           61         22440
# 3               1  Alameda  945027714.0           62         15708
# 4               1  Alameda  945027714.0           63         14960
#
#    Gallons_Used_Daily
# 0                 318
# 1                 405
# 2                 367
# 3                 253
# ...

# %%
water_drought.head()
# Out:
#    index   Pseudo_Id      Customer_Type Start_Date   End_Date  Ccf_Used  \
# 0      0  94502-4797  Res_Single_Family 2012-04-05 2012-06-05        26
# 1      1  94502-4797  Res_Single_Family 2012-06-05 2012-08-03        32
# 2      2  94502-4797  Res_Single_Family 2012-08-03 2012-10-03        30
# 3      3  94502-4797  Res_Single_Family 2012-10-03 2012-12-04        21
# 4      4  94502-4797  Res_Single_Family 2012-12-04 2013-02-05        20
#
#    Elevation_Band     City     Zip_Code  Billed_Days  Gallons_Used  \
# 0               1  Alameda  945027714.0           61         19448
# 1               1  Alameda  945027714.0           59         23936
# 2               1  Alameda  945027714.0           61         22440
# 3               1  Alameda  945027714.0           62         15708
# 4               1  Alameda  945027714.0           63         14960
#
#    Gallons_Used_Daily  Drought_Factor
# 0                 318       37.381672
# 1                 405       34.031593
# ...

# %%
water_drought.count()
# Out:
# index                 15053736
# Pseudo_Id             15053736
# Customer_Type         15053736
# Start_Date            15053736
# End_Date              15053736
# Ccf_Used              15053736
# Elevation_Band        15053736
# City                  15053736
# Zip_Code              15053736
# Billed_Days           15053736
# Gallons_Used          15053736
# Gallons_Used_Daily    15053736
# Drought_Factor        15053736
# dtype: int64

# %%
water_drought.to_csv('waterpj_fifteenmil.csv')

# %%
import seaborn as sns
import numpy as np

# %%
water_drought.head()
# Out:
#    index   Pseudo_Id      Customer_Type Start_Date   End_Date  Ccf_Used  \
# 0      0  94502-4797  Res_Single_Family 2012-04-05 2012-06-05        26
# 1      1  94502-4797  Res_Single_Family 2012-06-05 2012-08-03        32
# 2      2  94502-4797  Res_Single_Family 2012-08-03 2012-10-03        30
# 3      3  94502-4797  Res_Single_Family 2012-10-03 2012-12-04        21
# 4      4  94502-4797  Res_Single_Family 2012-12-04 2013-02-05        20
#
#    Elevation_Band     City     Zip_Code  Billed_Days  Gallons_Used  \
# 0               1  Alameda  945027714.0           61         19448
# 1               1  Alameda  945027714.0           59         23936
# 2               1  Alameda  945027714.0           61         22440
# 3               1  Alameda  945027714.0           62         15708
# 4               1  Alameda  945027714.0           63         14960
#
#    Gallons_Used_Daily  Drought_Factor
# 0                 318       37.381672
# 1                 405       34.031593
# ...

# %%
# Dividing out the Com from Res, as we will focus on Res water use.

# %%
water_drought.count()
# Out:
# index                 15053736
# Pseudo_Id             15053736
# Customer_Type         15053736
# Start_Date            15053736
# End_Date              15053736
# Ccf_Used              15053736
# Elevation_Band        15053736
# City                  15053736
# Zip_Code              15053736
# Billed_Days           15053736
# Gallons_Used          15053736
# Gallons_Used_Daily    15053736
# Drought_Factor        15053736
# dtype: int64

# %%
res_df = water_drought[water_drought['Customer_Type'].str.startswith('R')]

# %%
res_df.count()
# Out:
# index                 14921757
# Pseudo_Id             14921757
# Customer_Type         14921757
# Start_Date            14921757
# End_Date              14921757
# Ccf_Used              14921757
# Elevation_Band        14921757
# City                  14921757
# Zip_Code              14921757
# Billed_Days           14921757
# Gallons_Used          14921757
# Gallons_Used_Daily    14921757
# Drought_Factor        14921757
# dtype: int64

# %%
com_df = water_drought[water_drought['Customer_Type'].str.startswith('C')]

# %%
com_df.count()
# Out:
# index                 131979
# Pseudo_Id             131979
# Customer_Type         131979
# Start_Date            131979
# End_Date              131979
# Ccf_Used              131979
# Elevation_Band        131979
# City                  131979
# Zip_Code              131979
# Billed_Days           131979
# Gallons_Used          131979
# Gallons_Used_Daily    131979
# Drought_Factor        131979
# dtype: int64

# %%
# Always double checking to maintain data integrity

# %%
14921757 +  131979
# Out:
# 15053736

# %%
# Time to begin exploratory analysis

# %%
sns.scatterplot(x = 'Drought_Factor', y = 'Gallons_Used_Daily', hue = 'Customer_Type', s=10, data=res_df)
# Out:
# <AxesSubplot:xlabel='Drought_Factor', ylabel='Gallons_Used_Daily'>

# %%
del res_df['index']

# %%
res_df.head()
# Out:
#     Pseudo_Id      Customer_Type Start_Date   End_Date  Ccf_Used  \
# 0  94502-4797  Res_Single_Family 2012-04-05 2012-06-05        26
# 1  94502-4797  Res_Single_Family 2012-06-05 2012-08-03        32
# 2  94502-4797  Res_Single_Family 2012-08-03 2012-10-03        30
# 3  94502-4797  Res_Single_Family 2012-10-03 2012-12-04        21
# 4  94502-4797  Res_Single_Family 2012-12-04 2013-02-05        20
#
#    Elevation_Band     City     Zip_Code  Billed_Days  Gallons_Used  \
# 0               1  Alameda  945027714.0           61         19448
# 1               1  Alameda  945027714.0           59         23936
# 2               1  Alameda  945027714.0           61         22440
# 3               1  Alameda  945027714.0           62         15708
# 4               1  Alameda  945027714.0           63         14960
#
#    Gallons_Used_Daily  Drought_Factor
# 0                 318       37.381672
# 1                 405       34.031593
# 2                 367       36.456459
# ...

# %%
sns.heatmap(res_df.corr(), annot = True, cmap = "coolwarm")
# Out:
# <AxesSubplot:>

# %%
apt_df = water_drought[water_drought['Customer_Type'].str.startswith('Res_A')]

# %%
apt_df.count()
# Out:
# index                 420680
# Pseudo_Id             420680
# Customer_Type         420680
# Start_Date            420680
# End_Date              420680
# Ccf_Used              420680
# Elevation_Band        420680
# City                  420680
# Zip_Code              420680
# Billed_Days           420680
# Gallons_Used          420680
# Gallons_Used_Daily    420680
# Drought_Factor        420680
# dtype: int64

# %%
apt_df.head()
# Out:
#       index   Pseudo_Id   Customer_Type Start_Date   End_Date  Ccf_Used  \
# 2163   2163  94501-9592  Res_Apartments 2012-04-26 2012-05-25       542
# 2164   2164  94501-9592  Res_Apartments 2012-05-25 2012-06-25       627
# 2165   2165  94501-9592  Res_Apartments 2012-06-25 2012-07-26       533
# 2166   2166  94501-9592  Res_Apartments 2012-07-26 2012-08-24       517
# 2167   2167  94501-9592  Res_Apartments 2012-08-24 2012-09-25       619
#
#       Elevation_Band     City Zip_Code  Billed_Days  Gallons_Used  \
# 2163               1  Alameda  94501.0           29        405416
# 2164               1  Alameda  94501.0           31        468996
# 2165               1  Alameda  94501.0           31        398684
# 2166               1  Alameda  94501.0           29        386716
# 2167               1  Alameda  94501.0           32        463012
#
#       Gallons_Used_Daily  Drought_Factor
# 2163               13979       34.350000
# 2164               15128       34.196387
# ...

# %%
420680/14921757
# Out:
# 0.02819239048055802

# %%
apt_gpd_sum = apt_df['Gallons_Used_Daily'].sum()

# %%
apt_gpd_sum
# Out:
# 1036370777

# %%
res_gpd_sum = res_df['Gallons_Used_Daily'].sum()

# %%
res_gpd_sum
# Out:
# 4249158931

# %%
4249158931 - 1036370777
# Out:
# 3212788154

# %%
1036370777 / 3212788154
# Out:
# 0.32257675493159826

# %%
# Appartments account for 2% of all accounts, and 32% of water use.

# %%
sns.heatmap(apt_df.corr(), annot = True, cmap = "coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x = 'Drought_Factor', y = 'Gallons_Used_Daily', hue = 'Customer_Type', s=10, data=apt_df)
# Out:
# <AxesSubplot:xlabel='Drought_Factor', ylabel='Gallons_Used_Daily'>

# %%
sinf_df = water_drought[water_drought['Customer_Type'].str.startswith('Res_S')]

# %%
sinf_df['Customer_Type'].unique()
# Out:
# <StringArray>
# ['Res_Single_Family']
# Length: 1, dtype: string

# %%
multf_df = water_drought[water_drought['Customer_Type'].str.startswith('Res_M')]

# %%
multf_df['Customer_Type'].unique()
# Out:
# <StringArray>
# ['Res_Multiple_Dwelling']
# Length: 1, dtype: string

# %%
frames = [sinf_df, multf_df]
notapt_df = pd.concat(frames)

# %%
notapt_df['Customer_Type'].unique()
# Out:
# <StringArray>
# ['Res_Single_Family', 'Res_Multiple_Dwelling']
# Length: 2, dtype: string

# %%
# res_df is all residential
# apt_df is all apartments
# sinf_df is all single family
# multf_df is all multi family
# notapt_df is single family plus multifamily
# norm_res_df is a copy of res_df for trimming outliers

# %%
sns.scatterplot(x = 'Drought_Factor', y = 'Gallons_Used_Daily', hue = 'Customer_Type', s=10, data=sinf_df)
# Out:
# <AxesSubplot:xlabel='Drought_Factor', ylabel='Gallons_Used_Daily'>

# %%
sns.histplot(res_df['Start_Date'], kde=True, bins = 28)
# Out:
# <AxesSubplot:xlabel='Start_Date', ylabel='Count'>

# %%
res_df.count()
# Out:
# Pseudo_Id             14921757
# Customer_Type         14921757
# Start_Date            14921757
# End_Date              14921757
# Ccf_Used              14921757
# Elevation_Band        14921757
# City                  14921757
# Zip_Code              14921757
# Billed_Days           14921757
# Gallons_Used          14921757
# Gallons_Used_Daily    14921757
# Drought_Factor        14921757
# dtype: int64

# %%
multf_df.count()
# Out:
# index                 815728
# Pseudo_Id             815728
# Customer_Type         815728
# Start_Date            815728
# End_Date              815728
# Ccf_Used              815728
# Elevation_Band        815728
# City                  815728
# Zip_Code              815728
# Billed_Days           815728
# Gallons_Used          815728
# Gallons_Used_Daily    815728
# Drought_Factor        815728
# dtype: int64

# %%
sns.lineplot("Start_Date", 'Drought_Factor', data =res_df)
# Out:
# C:\Users\detro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Start_Date', ylabel='Drought_Factor'>

# %%
# We should copy the dataframe so any normalizations we make to it don't backflow into the original data set. 

norm_res_df = res_df.copy()

# %%
norm_res_df.count()
# Out:
# Pseudo_Id             14921757
# Customer_Type         14921757
# Start_Date            14921757
# End_Date              14921757
# Ccf_Used              14921757
# Elevation_Band        14921757
# City                  14921757
# Zip_Code              14921757
# Billed_Days           14921757
# Gallons_Used          14921757
# Gallons_Used_Daily    14921757
# Drought_Factor        14921757
# dtype: int64

# %%
#Looking at the Interdecile Range
dec_1 = norm_res_df.quantile(0.10)
dec_10 = norm_res_df.quantile(0.90)
IDR = dec_10 - dec_1
print(IDR)
# Out:
# Ccf_Used                 36.000000
# Elevation_Band            1.000000
# Billed_Days               6.000000
# Gallons_Used          26928.000000
# Gallons_Used_Daily      454.000000
# Drought_Factor           76.497969
# dtype: float64

# %%
#figuring out the Skewness of the data, it is 46.6. Anything over 1 is high. This is HIGHLY skewed data due to outliers. 

print(norm_res_df['Gallons_Used_Daily'].skew())
norm_res_df['Gallons_Used_Daily'].describe()
# Out:
# 46.66242405867512
# count    1.492176e+07
# mean     2.847626e+02
# std      9.180730e+02
# min      0.000000e+00
# 25%      8.800000e+01
# 50%      1.540000e+02
# 75%      2.730000e+02
# max      5.078920e+05
# Name: Gallons_Used_Daily, dtype: float64

# %%
#Determining the top and bottom Deciles to shave off the over/under. 

print(norm_res_df['Gallons_Used_Daily'].quantile(0.10))
print(norm_res_df['Gallons_Used_Daily'].quantile(0.90))
# Out:
# 48.0
# 502.0

# %%
norm_res_df["Gallons_Used_Daily"] = np.where(norm_res_df["Gallons_Used_Daily"] <48.0, 48.0,norm_res_df['Gallons_Used_Daily'])
norm_res_df["Gallons_Used_Daily"] = np.where(norm_res_df["Gallons_Used_Daily"] >502.0, 502.0,norm_res_df['Gallons_Used_Daily'])
print(norm_res_df['Gallons_Used_Daily'].skew())
# Out:
# 0.9609758553029953

# %%
norm_res_df.count()
# Out:
# Pseudo_Id             14921757
# Customer_Type         14921757
# Start_Date            14921757
# End_Date              14921757
# Ccf_Used              14921757
# Elevation_Band        14921757
# City                  14921757
# Zip_Code              14921757
# Billed_Days           14921757
# Gallons_Used          14921757
# Gallons_Used_Daily    14921757
# Drought_Factor        14921757
# dtype: int64

# %%
res_df.count()
# Out:
# Pseudo_Id             14921757
# Customer_Type         14921757
# Start_Date            14921757
# End_Date              14921757
# Ccf_Used              14921757
# Elevation_Band        14921757
# City                  14921757
# Zip_Code              14921757
# Billed_Days           14921757
# Gallons_Used          14921757
# Gallons_Used_Daily    14921757
# Drought_Factor        14921757
# dtype: int64

# %%
print(norm_res_df['Gallons_Used_Daily'].skew())
# Out:
# 0.9609758553029953

# %%
print(res_df['Gallons_Used_Daily'].skew())
# Out:
# 46.66242405867512

# %%
sns.scatterplot(x = 'Drought_Factor', y = 'Gallons_Used_Daily', hue = 'Customer_Type', s=10, data=norm_res_df)
# Out:
# <AxesSubplot:xlabel='Drought_Factor', ylabel='Gallons_Used_Daily'>
# C:\Users\detro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
norm_res_df["Gallons_Used_Daily"] = np.where(norm_res_df["Gallons_Used_Daily"] <48.0, 48.0,norm_res_df['Gallons_Used_Daily'])
norm_res_df["Gallons_Used_Daily"] = np.where(norm_res_df["Gallons_Used_Daily"] >502.0, 502.0,norm_res_df['Gallons_Used_Daily'])
print(norm_res_df['Gallons_Used_Daily'].skew())
# Out:
# 0.9609758553029953

# %%
mid_res_df = res_df[res_df['Gallons_Used_Daily'] < 502]

# %%
mid_res_df.count()
# Out:
# Pseudo_Id             13416806
# Customer_Type         13416806
# Start_Date            13416806
# End_Date              13416806
# Ccf_Used              13416806
# Elevation_Band        13416806
# City                  13416806
# Zip_Code              13416806
# Billed_Days           13416806
# Gallons_Used          13416806
# Gallons_Used_Daily    13416806
# Drought_Factor        13416806
# dtype: int64

# %%
mid_res_df2 = mid_res_df[res_df['Gallons_Used_Daily'] > 48]
# Out:
# C:\Users\detro\AppData\Local\Temp\ipykernel_12080\41830474.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mid_res_df2 = mid_res_df[res_df['Gallons_Used_Daily'] > 48]

# %%
mid_res_df.count()
# Out:
# Pseudo_Id             13416806
# Customer_Type         13416806
# Start_Date            13416806
# End_Date              13416806
# Ccf_Used              13416806
# Elevation_Band        13416806
# City                  13416806
# Zip_Code              13416806
# Billed_Days           13416806
# Gallons_Used          13416806
# Gallons_Used_Daily    13416806
# Drought_Factor        13416806
# dtype: int64

# %%
print(mid_res_df['Gallons_Used_Daily'].skew())
# Out:
# 0.9040716959209831

# %%
print(norm_res_df['Drought_Factor'].quantile(0.10))
print(norm_res_df['Drought_Factor'].quantile(0.90))
# Out:
# 6.6794736842105245
# 83.17744262295085

# %%
mid_res_df.head()
# Out:
#     Pseudo_Id      Customer_Type Start_Date   End_Date  Ccf_Used  \
# 0  94502-4797  Res_Single_Family 2012-04-05 2012-06-05        26
# 1  94502-4797  Res_Single_Family 2012-06-05 2012-08-03        32
# 2  94502-4797  Res_Single_Family 2012-08-03 2012-10-03        30
# 3  94502-4797  Res_Single_Family 2012-10-03 2012-12-04        21
# 4  94502-4797  Res_Single_Family 2012-12-04 2013-02-05        20
#
#    Elevation_Band     City     Zip_Code  Billed_Days  Gallons_Used  \
# 0               1  Alameda  945027714.0           61         19448
# 1               1  Alameda  945027714.0           59         23936
# 2               1  Alameda  945027714.0           61         22440
# 3               1  Alameda  945027714.0           62         15708
# 4               1  Alameda  945027714.0           63         14960
#
#    Gallons_Used_Daily  Drought_Factor
# 0                 318       37.381672
# 1                 405       34.031593
# 2                 367       36.456459
# ...

# %%
sns.boxplot(x='Gallons_Used_Daily',fliersize=0, y='City', data=norm_res_df).set(title='Water_Use_By_City')
plt.xlabel('Gal_Used_Daily')
plt.ylabel('Cities')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12080\3062225413.py in <module>
#       1 sns.boxplot(x='Gallons_Used_Daily',fliersize=0, y='City', data=norm_res_df).set(title='Water_Use_By_City')
# ----> 2 plt.xlabel('Gal_Used_Daily')
#       3 plt.ylabel('Cities')
#
# NameError: name 'plt' is not defined

# %%
#SELBY's CCF GOT LOST WHEN WE CONCATONATED

# %%
# Selby is a tiny number of enteries, it needs to be dropped. 

mid_res_df['City'].value_counts()
# Out:
# Oakland          3771959
# Richmond         1459822
# Berkeley         1112900
# San Leandro      1053846
# Alameda           711616
# Danville          582265
# Castro Valley     545613
# San Ramon         492166
# Walnut Creek      438417
# El Cerrito        356139
# Hayward           351163
# San Lorenzo       317526
# Lafayette         283543
# Hercules          266726
# Pinole            228556
# San Pablo         223044
# Orinda            208606
# Albany            183943
# Moraga            151946
# Piedmont          138274
# Alamo             122595
# Rodeo             101192
# Kensington         91591
# Pleasant Hill      75734
# El Sobrante        64538
# Crockett           43941
# Emeryville         32357
# Diablo              6745
# Selby                 43
# Name: City, dtype: int64

# %%
mid_res_df = mid_res_df.drop(mid_res_df.index[mid_res_df['City'] == 'Selby'])

# %%
mid_res_df['City'].value_counts()
# Out:
# Oakland          3771959
# Richmond         1459822
# Berkeley         1112900
# San Leandro      1053846
# Alameda           711616
# Danville          582265
# Castro Valley     545613
# San Ramon         492166
# Walnut Creek      438417
# El Cerrito        356139
# Hayward           351163
# San Lorenzo       317526
# Lafayette         283543
# Hercules          266726
# Pinole            228556
# San Pablo         223044
# Orinda            208606
# Albany            183943
# Moraga            151946
# Piedmont          138274
# Alamo             122595
# Rodeo             101192
# Kensington         91591
# Pleasant Hill      75734
# El Sobrante        64538
# Crockett           43941
# Emeryville         32357
# Diablo              6745
# Name: City, dtype: int64

# %%
sns.boxplot(x='Gallons_Used_Daily',fliersize=0, y='City', data=mid_res_df).set(title='Water_Use_By_City')
# Out:
# [Text(0.5, 1.0, 'Water_Use_By_City')]

# %%
sns.boxplot(x='Drought_Factor',fliersize=0, y='City', data=mid_res_df).set(title='Drought_Intensity_By_city')
# Out:
# [Text(0.5, 1.0, 'Drought_Intensity_By_city')]

# %%
sns.boxplot(x='Gallons_Used_Daily',fliersize=0, y='Customer_Type', data=mid_res_df).set(title='Water_Use_By_Res_Type')
# Out:
# [Text(0.5, 1.0, 'Water_Use_By_Res_Type')]

# %%
mid_res_df.plot(kind='hexbin', x='Drought_Factor', y='Gallons_Used_Daily', gridsize = 8)
# Out:
# <AxesSubplot:xlabel='Drought_Factor', ylabel='Gallons_Used_Daily'>

# %%
sns.boxplot(x='Drought_Factor',fliersize=0, y='Elevation_Band', data=mid_res_df).set(title='Drought_Intensity_By_Elev')

# %%
mid_res_df.head()
# Out:
#     Pseudo_Id      Customer_Type Start_Date   End_Date  Ccf_Used  \
# 0  94502-4797  Res_Single_Family 2012-04-05 2012-06-05        26
# 1  94502-4797  Res_Single_Family 2012-06-05 2012-08-03        32
# 2  94502-4797  Res_Single_Family 2012-08-03 2012-10-03        30
# 3  94502-4797  Res_Single_Family 2012-10-03 2012-12-04        21
# 4  94502-4797  Res_Single_Family 2012-12-04 2013-02-05        20
#
#    Elevation_Band     City     Zip_Code  Billed_Days  Gallons_Used  \
# 0               1  Alameda  945027714.0           61         19448
# 1               1  Alameda  945027714.0           59         23936
# 2               1  Alameda  945027714.0           61         22440
# 3               1  Alameda  945027714.0           62         15708
# 4               1  Alameda  945027714.0           63         14960
#
#    Gallons_Used_Daily  Drought_Factor
# 0                 318       37.381672
# 1                 405       34.031593
# 2                 367       36.456459
# ...

# %%
mid_res_df.round(2).describe()
# Out:
#             Ccf_Used  Elevation_Band    Billed_Days   Gallons_Used  \
# count 13416763.00000  13416763.00000 13416763.00000 13416763.00000
# mean        13.14226         1.45921       59.42825     9830.40821
# std          8.95071         0.63235        8.16661     6695.13163
# min          0.00000         1.00000        1.00000        0.00000
# 25%          6.00000         1.00000       59.00000     4488.00000
# 50%         11.00000         1.00000       61.00000     8228.00000
# 75%         18.00000         2.00000       62.00000    13464.00000
# max        156.00000         3.00000      956.00000   116688.00000
#
#        Gallons_Used_Daily  Drought_Factor
# count      13416763.00000  13416763.00000
# mean            164.10119        49.29385
# std             110.10708        27.93278
# min               0.00000         1.22000
# 25%              83.00000        29.26000
# 50%             140.00000        49.09000
# 75%             224.00000        79.87000
# ...

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
sns.histplot(mid_res_df['Drought_Factor'], kde=True, bins = 35)
# Out:
# <AxesSubplot:xlabel='Drought_Factor', ylabel='Count'>

# %%
sns.boxplot(x='Elevation_Band',fliersize=0, y='Gallons_Used_Daily', data=mid_res_df).set(title='Water_Use_By_Elevation_Band')
# Out:
# [Text(0.5, 1.0, 'Water_Use_By_Elevation_Band')]

# %%
sns.boxplot(x='Elevation_Band',fliersize=0, y='Drought_Factor', data=mid_res_df).set(title='Drought_Factor_By_Elevation_Band')
# Out:
# [Text(0.5, 1.0, 'Drought_Factor_By_Elevation_Band')]

# %%
mid_res_df.head()
# Out:
#     Pseudo_Id      Customer_Type Start_Date   End_Date  Ccf_Used  \
# 0  94502-4797  Res_Single_Family 2012-04-05 2012-06-05        26
# 1  94502-4797  Res_Single_Family 2012-06-05 2012-08-03        32
# 2  94502-4797  Res_Single_Family 2012-08-03 2012-10-03        30
# 3  94502-4797  Res_Single_Family 2012-10-03 2012-12-04        21
# 4  94502-4797  Res_Single_Family 2012-12-04 2013-02-05        20
#
#    Elevation_Band     City     Zip_Code  Billed_Days  Gallons_Used  \
# 0               1  Alameda  945027714.0           61         19448
# 1               1  Alameda  945027714.0           59         23936
# 2               1  Alameda  945027714.0           61         22440
# 3               1  Alameda  945027714.0           62         15708
# 4               1  Alameda  945027714.0           63         14960
#
#    Gallons_Used_Daily  Drought_Factor
# 0                 318        37.38167
# 1                 405        34.03159
# 2                 367        36.45646
# ...

# %%
group_res_df=mid_res_df.groupby(['City'],['Gallons_Used_Daily']).mean()

# %%
mid_res_df.groupby('City').Gallons_Used_Daily.mean().sort_values()
# Out:
# City
# Albany          127.14533
# El Cerrito      134.28727
# Berkeley        138.76147
# Emeryville      139.83654
# Crockett        144.70178
# Oakland         146.68392
# Kensington      150.71937
# Alameda         154.17201
# Richmond        156.51628
# San Leandro     162.95190
# El Sobrante     164.94301
# San Pablo       166.26874
# Pinole          169.68726
# San Lorenzo     170.65270
# Hayward         172.96715
# Rodeo           173.54618
# Castro Valley   179.53826
# Hercules        181.98073
# Walnut Creek    194.10128
# Piedmont        199.04873
# Orinda          206.56749
# Lafayette       209.36459
# Moraga          209.70356
# Pleasant Hill   210.96233
# Danville        213.10501
# San Ramon       214.71408
# Alamo           231.62883
# Diablo          237.22713
# Name: Gallons_Used_Daily, dtype: float64

# %%
mid_res_df.groupby('City').Gallons_Used_Daily.mean().mean()
# Out:
# 177.20653355617907

# %%
water_mean_city = mid_res_df.groupby('City').Gallons_Used_Daily.mean()

# %%
water_mean_city.head()
# Out:
# City
# Alameda         154.17201
# Alamo           231.62883
# Albany          127.14533
# Berkeley        138.76147
# Castro Valley   179.53826
# Name: Gallons_Used_Daily, dtype: float64

# %%
water_mean_city.columns =['City', 'Mean_GUD']

# %%
water_mean_city.plot.bar(x='Mean_GUD', y='City', rot=90).set(title='Mean_Gal_Used_Daily');

# %%
drought_mean_city = mid_res_df.groupby('City').Drought_Factor.mean()

# %%
drought_mean_city.columns =['City', 'Mean_DF']

# %%
drought_mean_city.plot.bar(x='City', y='Mean_DF', rot=90).set(title='Mean_Drought_Factor');

# %%
mid_res_df.groupby('Customer_Type').Gallons_Used_Daily.mean()
# Out:
# Customer_Type
# Res_Apartments          274.51053
# Res_Multiple_Dwelling   235.24898
# Res_Single_Family       159.57216
# Name: Gallons_Used_Daily, dtype: float64

# %%
res_df.groupby('Customer_Type').Gallons_Used_Daily.mean()
# Out:
# Customer_Type
# Res_Apartments          2463.56085
# Res_Multiple_Dwelling    334.44784
# Res_Single_Family        214.82607
# Name: Gallons_Used_Daily, dtype: float64

# %%
res_df.groupby('Customer_Type').Gallons_Used_Daily.mean()

# %%
mid_res_df.groupby('City').Gallons_Used_Daily.mean().sort_values()
# Out:
# City
# Albany          127.14533
# El Cerrito      134.28727
# Berkeley        138.76147
# Emeryville      139.83654
# Crockett        144.70178
# Oakland         146.68392
# Kensington      150.71937
# Alameda         154.17201
# Richmond        156.51628
# San Leandro     162.95190
# El Sobrante     164.94301
# San Pablo       166.26874
# Pinole          169.68726
# San Lorenzo     170.65270
# Hayward         172.96715
# Rodeo           173.54618
# Castro Valley   179.53826
# Hercules        181.98073
# Walnut Creek    194.10128
# Piedmont        199.04873
# Orinda          206.56749
# Lafayette       209.36459
# Moraga          209.70356
# Pleasant Hill   210.96233
# Danville        213.10501
# San Ramon       214.71408
# Alamo           231.62883
# Diablo          237.22713
# Name: Gallons_Used_Daily, dtype: float64

# %%
mid_res_df.groupby('City').Drought_Factor.mean().sort_values()
# Out:
# City
# Crockett        43.07441
# Castro Valley   43.14539
# Diablo          49.10749
# Alamo           49.17600
# Rodeo           49.31647
# San Lorenzo     49.35304
# Hercules        49.35711
# Albany          49.42965
# Berkeley        49.43067
# Oakland         49.44157
# Orinda          49.50989
# Alameda         49.51133
# Richmond        49.54634
# Piedmont        49.57084
# Walnut Creek    49.63353
# Danville        49.64361
# Pinole          49.67861
# San Ramon       49.73856
# San Leandro     49.80861
# El Sobrante     49.83007
# San Pablo       49.85702
# Pleasant Hill   49.89317
# Kensington      49.91215
# El Cerrito      49.93783
# Hayward         49.94313
# Lafayette       50.01012
# Emeryville      50.03015
# Moraga          50.05888
# Name: Drought_Factor, dtype: float64

# %%
mid_res_df.groupby('City').Elevation_Band.mean().sort_values()
# Out:
# City
# Alameda         1.00000
# San Lorenzo     1.00000
# Emeryville      1.00000
# Albany          1.00520
# Pleasant Hill   1.01956
# San Pablo       1.04597
# San Leandro     1.05545
# Rodeo           1.20671
# Richmond        1.22704
# Pinole          1.27152
# Hercules        1.37595
# Walnut Creek    1.38763
# Oakland         1.40747
# Hayward         1.42705
# Crockett        1.44687
# El Cerrito      1.45534
# Berkeley        1.50672
# Piedmont        1.56341
# El Sobrante     1.75813
# Castro Valley   1.90456
# Alamo           1.99476
# Lafayette       2.02264
# San Ramon       2.05990
# Diablo          2.17746
# Kensington      2.25646
# Danville        2.28704
# Moraga          2.35222
# Orinda          2.63426
# Name: Elevation_Band, dtype: float64

# %%
sns.heatmap(mid_res_df.corr(), annot = True, cmap = "coolwarm")
# Out:
# <AxesSubplot:>

# %%
mid_res_df.groupby('City').Drought_Factor.mean().mean()
# Out:
# 49.1766307172767

# %%
sns.boxplot(x='Gallons_Used_Daily',fliersize=0, palette="Set3", y='Customer_Type', data=mid_res_df).set(title='Water_Use_By_Res_Type')
# Out:
# [Text(0.5, 1.0, 'Water_Use_By_Res_Type')]

# %%
sns.violinplot(x ='Gallons_Used_Daily', y ='Customer_Type', palette="Set3", data = mid_res_df)
# Out:
# <AxesSubplot:xlabel='Gallons_Used_Daily', ylabel='Customer_Type'>

# %%
data = mid_res_df
res = sns.kdeplot(data['Gallons_Used_Daily'],data['Drought_Factor'],shade=True,cmap="Blues")
plt.show()
# Out:
# C:\Users\detro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12080\229842358.py in <module>
#       1 data = mid_res_df
#       2 res = sns.kdeplot(data['Gallons_Used_Daily'],data['Drought_Factor'],shade=True,cmap="Blues")
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
mid_res_df['Gallons_Used_Daily'].corr(mid_res_df['Drought_Factor'])
# Out:
# -0.001886137644247476

# %%
mid_res_df.groupby('City').Drought_Factor.median()
# Out:
# City
# Alameda         48.60229
# Alamo           47.77635
# Albany          50.94134
# Berkeley        50.28803
# Castro Valley   36.25682
# Crockett        35.30610
# Danville        50.66142
# Diablo          49.39838
# El Cerrito      52.84963
# El Sobrante     54.70842
# Emeryville      57.16292
# Hayward         54.39268
# Hercules        52.28475
# Kensington      51.89723
# Lafayette       54.87607
# Moraga          55.26630
# Oakland         50.17386
# Orinda          50.10526
# Piedmont        52.28610
# Pinole          47.28759
# Pleasant Hill   54.01305
# Richmond        49.66872
# Rodeo           53.30728
# San Leandro     54.39997
# San Lorenzo     53.54766
# San Pablo       55.10964
# San Ramon       52.99317
# Walnut Creek    52.99317
# Name: Drought_Factor, dtype: float64
